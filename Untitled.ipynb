# %%
# %load_ext gams_magic
# Out:
# ---------------------------------------------------------------------------
# GamsException                             Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 get_ipython().run_line_magic('load_ext', 'gams_magic')
#
# File /usr/local/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2309, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2307     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2308 with self.builtin_trap:
# -> 2309     result = fn(*args, **kwargs)
#    2310 return result
#
# File /usr/local/lib/python3.10/site-packages/IPython/core/magics/extension.py:33, in ExtensionMagics.load_ext(self, module_str)
#      31 if not module_str:
#      32     raise UsageError('Missing module name.')
# ---> 33 res = self.shell.extension_manager.load_extension(module_str)
#      35 if res == 'already loaded':
#      36     print("The %s extension is already loaded. To reload it, use:" % module_str)
#
# ...

# %%
# %%gams
# $include "GE-1-2-3.gms"
# Out:
#   Solver Status Model Status  Objective #equ #var Model Type  Solver  \
# 0    Normal (1)  Solved (16)        0.0    7    8        CNS  CONOPT
#
#   Solver Time
# 0       0.002

# %%
# %gams display C.l;
# %gams_lst -e
# Out:
# E x e c u t i o n
#
#
# ----    223 VARIABLE C.L                   =        1.000  Consumption

# %%
# %gams_pull omega

# %%
omega
# Out:
# [-2.0]

# %% [markdown]
# Increase tariff to 50%

# %%
t = 0.5
# %gams_push t
# %gams solve GE123 using cns;
# Out:
#   Solver Status Model Status  Objective #equ #var Model Type  Solver  \
# 0    Normal (1)  Solved (16)        0.0    7    8        CNS  CONOPT
#
#   Solver Time
# 0       0.002

# %%
# %gams_lst
# Out:
# GAMS 40.3.0  f227c22a Sep 16, 2022          LEX-LEG x86 64bit/Linux - 09/27/22 14:13:51 Page 64
# 1-2-3 GE model
# C o m p i l a t i o n
#
#
#  230  solve GE123 using cns;
#
#
# COMPILATION TIME     =        0.001 SECONDS      2 MB  40.3.0 f227c22a LEX-LEG
# GAMS 40.3.0  f227c22a Sep 16, 2022          LEX-LEG x86 64bit/Linux - 09/27/22 14:13:51 Page 65
# 1-2-3 GE model
# Equation Listing    SOLVE GE123 Using CNS From line 230
#
#
# ---- EQ_C  =E=
#
# EQ_C..  (1)*C - (0.05)*M + (1)*PC - PY - (0.05)*E =E= 0 ; (LHS = -1.05, INFES = 1.05 ****)
#
#
# ---- EQ_M  =E=
#
# EQ_M..  - (0.296296296296296)*C + M - (0.888888888888889)*PC + (0.888888888888889)*E =E= 0 ; (LHS = 0.703703703703704, INFES = 0.703703703703704 ****)
#
#
# ---- EQ_PC  =E=
#
# EQ_PC..  PC - (0.0484231299225907)*E - (0.980568380932462)*P =E= 0 ; (LHS = -0.0289915108550531, INFES = 0.0289915108550531 ****)
#
#
# ---- EQ_X  =E=
#
# EQ_X..  X + (0.25)*PY - (0.5)*E =E= 0 ; (LHS = 0.75, INFES = 0.75 ****)
#
#
# ---- EQ_PY  =E=
# ...
