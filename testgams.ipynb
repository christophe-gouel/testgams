# %%
# %load_ext gams_magic

# %%
# %%gams
# $include "GE-1-2-3.gms"
# Out:
#   Solver Status Model Status  Objective #equ #var Model Type  Solver  \
# 0    Normal (1)  Solved (16)        0.0    7    8        CNS  CONOPT
#
#   Solver Time
# 0       0.006

# %%
# %gams display C.l;
# %gams_lst -e
# Out:
# E x e c u t i o n
#
#
# ----     92 VARIABLE C.L                   =        1.000  Consumption

# %%
# %gams_pull omega

# %%
omega
# Out:
# [-2.0]

# %% [markdown]
# Increase tariff to 50%

# %%
t = 0.5
# %gams_push t
# %gams solve GE123 using cns;
# Out:
#   Solver Status Model Status  Objective #equ #var Model Type  Solver  \
# 0    Normal (1)  Solved (16)        0.0    7    8        CNS  CONOPT
#
#   Solver Time
# 0       0.004

# %%
# %gams_lst
# Out:
# GAMS 40.3.0  f227c22a Sep 16, 2022          LEX-LEG x86 64bit/Linux - 09/28/22 13:29:38 Page 14
# 1-2-3 GE model
# C o m p i l a t i o n
#
#
#   99  solve GE123 using cns;
#
#
# COMPILATION TIME     =        0.000 SECONDS      2 MB  40.3.0 f227c22a LEX-LEG
# GAMS 40.3.0  f227c22a Sep 16, 2022          LEX-LEG x86 64bit/Linux - 09/28/22 13:29:38 Page 15
# 1-2-3 GE model
# Equation Listing    SOLVE GE123 Using CNS From line 99
#
#
# ---- EQ_C  =E=
#
# EQ_C..  (1)*C - (0.05)*M + (1)*PC - PY - (0.05)*E =E= 0 ; (LHS = -1.05, INFES = 1.05 ****)
#
#
# ---- EQ_M  =E=
#
# EQ_M..  - (0.296296296296296)*C + M - (0.888888888888889)*PC + (0.888888888888889)*E =E= 0 ; (LHS = 0.703703703703704, INFES = 0.703703703703704 ****)
#
#
# ---- EQ_PC  =E=
#
# EQ_PC..  PC - (0.0484231299225907)*E - (0.980568380932462)*P =E= 0 ; (LHS = -0.0289915108550531, INFES = 0.0289915108550531 ****)
#
#
# ---- EQ_X  =E=
#
# EQ_X..  X + (0.25)*PY - (0.5)*E =E= 0 ; (LHS = 0.75, INFES = 0.75 ****)
#
#
# ---- EQ_PY  =E=
#
# ...

# %%
# %gams_cleanup -k
